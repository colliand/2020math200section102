# %% [markdown]
# # Space and Vectors

# %% [markdown]
# ## Three Dimensional Coordinate Systems

# %% [markdown]
# **The Real Numbers**
# $$ \mathbb{R} = \{x ~ | -\infty < x <+ \infty \}$$

# %% [markdown]
# $$ \mathbb{R}^2 = \{(x,y) ~ | x \in \mathbb{R}, y \in \mathbb{R}\}$$

# %% [markdown]
# $$ \mathbb{R}^3 = \{(x,y,z) ~ | x \in \mathbb{R}, y \in \mathbb{R}, z \in \mathbb{R}\}$$

# %% [markdown]
# ## Visualizing $\mathbb{R}^3$

# %%
from mpl_toolkits import mplot3d

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %% [markdown]
# ## Some interesting subsets of $\mathbb{R}^3$

# %% [markdown]
# ### Describe the sets?
# + $\{ (x,y,z) \in \mathbb{R}^3 |~ z = 0 \}$?

# %% [markdown]
# + $\{ z = 12 \}$

# %% [markdown]
# + $\{ x = 3 \} $

# %% [markdown]
# + $\{ y = x \}$

# %% [markdown]
# Count the free parameters to get some intuition on the subset.

# %% [markdown]
# ## Distance between points in space

# %% [markdown]
# Consider two points in space:
# + $P_1$ with coordinates $(x_1, y_1, z_1)$
# + $P_2$ with coordinates $(x_2, y_2, z_2)$

# %% [markdown]
# ### What's the distance between $P_1$ and $P_2$?

# %% [markdown]
# Simplify to develop intution.
# + Set $z_1 = z_2 = 0$.

# %% [markdown]
# + Move $P_2$ to origin:
# $$x_2 = y_2 = z_2 = 0.$$

# %% [markdown]
# ### The distance between two points in space is
# $$d(P_1, P_2) = \sqrt{ (x_2 - x_1)^2 + (y_2 - y_1)^2 + (z_2 - z_1)^2}$$

# %% [markdown]
# ## [Pythagorean Theorem](https://en.wikipedia.org/wiki/Pythagorean_theorem)

# %% [markdown]
# ![pythagorean proof visualized](https://upload.wikimedia.org/wikipedia/commons/6/65/Pythag_anim.gif)

# %% [markdown]
# ## Describe this set?
#
# $$\{ (x,y,z) \in \mathbb{R}^3 ~|~ \sqrt{ (x - a)^2 + (y - b)^2 + (z - c)^2} = r \}$$

# %% [markdown]
# ## $f: \mathbb{R}^2 \longmapsto \mathbb{R}$
#
# (a foreshadow of where we are headed)

# %%
def f(x, y):
    return np.sin(np.sqrt( x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('surface');

# %% [markdown]
# ## Vectors

# %% [markdown]
# A **vector** is a quantity with a **magnitude** AND a **direction**.

# %% [markdown]
# Often, we think of vectors as "arrows" attached to a point in space.

# %% [markdown]
# If we put the base of the vector at the origin, we can associate the vector with the coordinates of its endpoint:
# $$ {\bf{a}} = \langle a_1, a_2, a_3 \rangle$$

# %% [markdown]
# The **magnitude** of a vector $ {\bf{a}} = \langle a_1, a_2, a_3 \rangle$ is
# $$ | {\bf{a}} | = \sqrt{ a_1^2 + a_2^2 + a_3^2 }.$$

# %% [markdown]
# The **zero vector** is ${\bf{0}} = \langle 0,0,0 \rangle.$

# %% [markdown]
# + ${\bf{0}}$ has zero magnitude.
# + ${\bf{0}}$ has no direction.

# %% [markdown]
# ## Vector Addition

# %% [markdown]
# + concatentate the arrows tip-to-tail
# + formula for adding vectors

# %% [markdown]
# ## Multiplying a Vector by a Scalar

# %% [markdown]
# ## What's a *scalar*?

# %% [markdown]
# Let $c \in \mathbb{R}$. Let ${\bf{v}} = \langle v_1, v_2, v_3 \rangle$ be a vector.

# %% [markdown]
# How should we understand the expression $c {\bf{v}}$? What if $c<0$?

# %% [markdown]
# $c {\bf{v}} = \langle c v_1, c v_2, c v_3 \rangle$
